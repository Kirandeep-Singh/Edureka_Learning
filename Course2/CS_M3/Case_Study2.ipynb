# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %%
df = pd.read_csv('cereal.csv')

df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
df1 = df[['name','sugars','vitamins']]
df1
# Out:
#                          name  sugars  vitamins
# 0                   100% Bran       6        25
# 1           100% Natural Bran       8         0
# 2                    All-Bran       5        25
# 3   All-Bran with Extra Fiber       0        25
# 4              Almond Delight       8        25
# ..                        ...     ...       ...
# 72                    Triples       3        25
# 73                       Trix      12        25
# 74                 Wheat Chex       3        25
# 75                   Wheaties       3        25
# 76        Wheaties Honey Gold       8        25
#
# [77 rows x 3 columns]

# %%
bins = np.linspace(0, 1.0, 40)
plt.figure(figsize=(10,10))
plt.hist(df1[['sugars','vitamins']], alpha = 0.5, label=df1['name'])
plt.legend()

# %%
new = {'N': 'Nabisco',
'Q': 'Quaker Oats',
'K': 'Kelloggs',
'R': 'Raslston Purina',
'G': 'General Mills' ,
'P' :'Post' ,
'A':'American Home Foods Products'}

for i in range(0,len(df)):
    df.at[i , 'mfrs'] = new[df.iloc[i]['mfr']]

# %%
sns.countplot(df['mfrs'], orient='v')
plt.xticks(rotation=90)
##unabel to plot horizontally Please suggest in review
## will plot with bar plot
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]), <a list of 7 Text xticklabel objects>)

# %%
new = dict(df.groupby('mfrs').count()['name'])
lt = []
lt1 = []

for i in new.keys():
    lt.append(i)

for i in new.values():
    lt1.append(i)

plt.barh(lt,lt1, color='k')
plt.xlabel('Count of Cereals by manufacturer')
plt.ylabel('Name of Manufacturer')
plt.title('Manufacturer vs Count')
# Out:
# Text(0.5, 1.0, 'Manufacturer vs Count')

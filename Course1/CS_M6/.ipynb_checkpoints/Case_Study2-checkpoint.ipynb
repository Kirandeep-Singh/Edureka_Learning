# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('BigMartSalesData.csv')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#    UnitPrice  Amount InvoiceDate  Day  Month  Year  CustomerID         Country
# 0       2.55   15.30    01-12-10    1     12  2010     17850.0  United Kingdom
# 1       3.39   20.34    01-12-10    1     12  2010     17850.0  United Kingdom
# 2       2.75   22.00    01-12-10    1     12  2010     17850.0  United Kingdom
# 3       3.39   20.34    01-12-10    1     12  2010     17850.0  United Kingdom
# 4       3.39   20.34    01-12-10    1     12  2010     17850.0  United Kingdom

# %%
df1 = pd.DataFrame()
tmpdf = df[df['Year'] == 2011]
df1['Month'] = tmpdf['Month']
df1['Amount'] = tmpdf['Amount']
tmp = df1.groupby('Month').sum()

dict = tmp.to_dict()['Amount']

x = [i for i in dict.keys()]
y = [i for i in dict.values()]

plt.figure(figsize=(10,10), dpi=200)
fig, ax = plt.subplots(2)
fig.suptitle('Both Graphs Together')
ax[0].bar(x,y)
ax[1].plot(x,y)

# %%
df2 = pd.DataFrame()

df2['Country'] = tmpdf['Country']
df2['Amount'] = tmpdf['Amount']
tmp = df2.groupby('Country').sum()

country_dict = tmp.to_dict()['Amount']
plt.figure(figsize=(10,10))

plt.pie([float(i) for i in country_dict.values()], labels=(country_dict.keys()), autopct='%d')
# Out:
# ([<matplotlib.patches.Wedge at 0x1e103672e88>,
#   <matplotlib.patches.Wedge at 0x1e1036677c8>,
#   <matplotlib.patches.Wedge at 0x1e10365a088>,
#   <matplotlib.patches.Wedge at 0x1e10365aa08>,
#   <matplotlib.patches.Wedge at 0x1e103804648>,
#   <matplotlib.patches.Wedge at 0x1e10380c088>,
#   <matplotlib.patches.Wedge at 0x1e10380c748>,
#   <matplotlib.patches.Wedge at 0x1e1038150c8>,
#   <matplotlib.patches.Wedge at 0x1e103804388>,
#   <matplotlib.patches.Wedge at 0x1e103804d88>,
#   <matplotlib.patches.Wedge at 0x1e1656cccc8>,
#   <matplotlib.patches.Wedge at 0x1e1038284c8>,
#   <matplotlib.patches.Wedge at 0x1e103828e08>,
#   <matplotlib.patches.Wedge at 0x1e103832788>,
#   <matplotlib.patches.Wedge at 0x1e10383d108>,
#   <matplotlib.patches.Wedge at 0x1e10383da48>,
#   <matplotlib.patches.Wedge at 0x1e1038453c8>,
#   <matplotlib.patches.Wedge at 0x1e103845d08>,
#   <matplotlib.patches.Wedge at 0x1e10384f688>,
#   <matplotlib.patches.Wedge at 0x1e10384ffc8>,
#   <matplotlib.patches.Wedge at 0x1e10385a948>,
#   <matplotlib.patches.Wedge at 0x1e1038632c8>,
#   <matplotlib.patches.Wedge at 0x1e103863c08>,
#   <matplotlib.patches.Wedge at 0x1e10386c588>,
#   <matplotlib.patches.Wedge at 0x1e10386cec8>,
#   <matplotlib.patches.Wedge at 0x1e103875848>,
#   <matplotlib.patches.Wedge at 0x1e10387f1c8>,
#   <matplotlib.patches.Wedge at 0x1e10387fb08>,
#   <matplotlib.patches.Wedge at 0x1e103885488>,
#   <matplotlib.patches.Wedge at 0x1e103885dc8>,
#   <matplotlib.patches.Wedge at 0x1e10388f748>,
#   <matplotlib.patches.Wedge at 0x1e1038990c8>,
#   <matplotlib.patches.Wedge at 0x1e103899a08>,
#   <matplotlib.patches.Wedge at 0x1e1038a1388>,
#   <matplotlib.patches.Wedge at 0x1e1038a1cc8>,
#   <matplotlib.patches.Wedge at 0x1e1038ac648>,
#   <matplotlib.patches.Wedge at 0x1e1038acf88>],
#  [Text(1.0990753501064356, 0.04509295719307135, 'Australia'),
#   Text(1.0960336675107423, 0.09332845055475883, 'Austria'),
#   Text(1.0957334115821273, 0.09678993099797358, 'Bahrain'),
#   Text(1.0945003370647075, 0.10985905590911366, 'Belgium'),
#   Text(1.0930972505214924, 0.12303820911551723, 'Brazil'),
#   Text(1.092921444216892, 0.12459019532396215, 'Canada'),
#   Text(1.092006728139989, 0.1323680690234484, 'Channel Islands'),
#   Text(1.090661444711935, 0.14303011228015983, 'Cyprus'),
#   Text(1.0900788857005708, 0.14740428402798314, 'Czech Republic'),
#   Text(1.089243727970711, 0.15345390538030673, 'Denmark'),
#   Text(1.0706285452833395, 0.25249657032221373, 'EIRE'),
#   Text(1.0447220907326231, 0.34431926047675143, 'European Community'),
#   Text(1.0423413990378654, 0.351460393005792, 'Finland'),
#   Text(1.0155666713378222, 0.422639723722009, 'France'),
#   Text(0.953488709145005, 0.548506409746497, 'Germany'),
#   Text(0.9149939851183447, 0.6105620420540819, 'Greece'),
#   Text(0.9102667950717115, 0.6175875337066601, 'Hong Kong'),
#   Text(0.9057091270261968, 0.6242523345742846, 'Iceland'),
#   Text(0.9035414412870436, 0.6273857377060242, 'Israel'),
#   Text(0.8988150836432032, 0.6341383487973755, 'Italy'),
#   Text(0.8895420038517771, 0.6470819294211246, 'Japan'),
#   Text(0.8831031164960732, 0.6558421194425708, 'Lebanon'),
#   Text(0.882204033660356, 0.6570510200839793, 'Malta'),
#   Text(0.8248598595777997, 0.7277404840032556, 'Netherlands'),
#   Text(0.7547082593011284, 0.8002596099658291, 'Norway'),
#   Text(0.7450657765277703, 0.8092447025758468, 'Poland'),
#   Text(0.734773483225721, 0.8186012022641679, 'Portugal'),
#   Text(0.7258790128225255, 0.8264984323904045, 'RSA'),
#   Text(0.7255952206554396, 0.8267475889060603, 'Saudi Arabia'),
#   Text(0.7173595832795414, 0.8339036085046058, 'Singapore'),
#   Text(0.692440067048981, 0.8547085781394749, 'Spain'),
#   Text(0.666478333189368, 0.8751037832103813, 'Sweden'),
#   Text(0.6425668742663097, 0.8928089449012173, 'Switzerland'),
#   Text(0.6261409775724994, 0.9044044870546336, 'USA'),
#   Text(0.6241819567544045, 0.9057576303085958, 'United Arab Emirates'),
#   Text(-0.9743801323964709, -0.5104736600364764, 'United Kingdom'),
#   Text(1.0999989181579324, -0.0015427415139254042, 'Unspecified')],
#  [Text(0.5994956455126011, 0.024596158468948005, '1'),
#   Text(0.5978365459149503, 0.050906427575322995, '0'),
#   Text(0.5976727699538875, 0.05279450781707649, '0'),
#   Text(0.5970001838534768, 0.05992312140497108, '0'),
#   Text(0.5962348639208139, 0.06711175042664576, '0'),
#   Text(0.5961389695728502, 0.0679582883585248, '0'),
#   Text(0.595640033530903, 0.07220076492188092, '0'),
#   Text(0.5949062425701462, 0.07801642488008717, '0'),
#   Text(0.5945884831094022, 0.08040233674253626, '0'),
#   Text(0.5941329425294787, 0.08370213020744004, '0'),
#   Text(0.5839792065181851, 0.13772540199393477, '2'),
#   Text(0.5698484131268853, 0.18781050571459165, '0'),
#   Text(0.5685498540206537, 0.19170566891225016, '0'),
#   Text(0.5539454570933574, 0.23053075839382306, '1'),
#   Text(0.52008475044273, 0.29918531440718016, '2'),
#   Text(0.4990876282463698, 0.3330338411204083, '0'),
#   Text(0.4965091609482062, 0.33686592747636, '0'),
#   Text(0.49402316019610726, 0.34050127340415526, '0'),
#   Text(0.4928407861565692, 0.3422104023851041, '0'),
#   Text(0.4902627728962926, 0.34589364479856843, '0'),
#   Text(0.4852047293736965, 0.35295377968424974, '0'),
#   Text(0.48169260899785804, 0.3577320651504931, '0'),
#   Text(0.48120220017837595, 0.3583914655003523, '0'),
#   Text(0.4499235597697089, 0.39694935491086664, '2'),
#   Text(0.41165905052788815, 0.4365052417995431, '0'),
#   Text(0.40639951446969286, 0.4414062014050073, '0'),
#   Text(0.4007855363049387, 0.44650974668954607, '0'),
#   Text(0.3959340069941048, 0.4508173267584024, '0'),
#   Text(0.39577921126660337, 0.4509532303123964, '0'),
#   Text(0.39128704542520437, 0.4548565137297849, '0'),
#   Text(0.37769458202671685, 0.46620467898516804, '0'),
#   Text(0.3635336362851098, 0.47732933629657154, '0'),
#   Text(0.35049102232707796, 0.48698669721884574, '0'),
#   Text(0.34153144231227234, 0.49331153839343644, '0'),
#   Text(0.3404628855024024, 0.4940496165319613, '0'),
#   Text(-0.5314800722162568, -0.2784401782017144, '84'),
#   Text(0.5999994099043267, -0.0008414953712320385, '0')])

# %%
# Out:
# 0         2010
# 1         2010
# 2         2010
# 3         2010
# 4         2010
#           ...
# 541869    2011
# 541870    2011
# 541871    2011
# 541872    2011
# 541873    2011
# Name: Year, Length: 541874, dtype: int64
